# %% [markdown]
# **Install Libraries**
#
# We will leverage Pandas to scrape, analyze, and visualize our data.

# %%
import pandas as pd

# %% [markdown]
# **Scraping Data**
#
# We get our incident data from `www.fire.ca.gov`

# %%
url_2016 = 'https://www.fire.ca.gov/incidents/2016'
